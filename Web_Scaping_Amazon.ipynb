# %%
# Requires: requests, beautifulsoup4
import requests
from bs4 import BeautifulSoup
import time
import re

# %%
URL = "https://www.amazon.in/s?k=laptop&crid=31TPTM1NJVMEC&sprefix=laptop%2Caps%2C355&ref=nb_sb_noss_2"

# %%
# make header to mimic a browser visit
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/144.0.0.0 Safari/537.36"
}

# %%
# Create a empty list to store laptop Details

data = []
print("Data list cleared")
# Out:
# Data list cleared

# %%
for page in range(1, 2):  
    params = {"k": "laptop", "page": page}
    
    # Use verify=False to bypass SSL verification (for testing purposes)
    response = requests.get(URL, params=params, headers=headers)
    soup = BeautifulSoup(response.text, "html.parser")
    
    products = soup.find_all("div", {"data-component-type": "s-search-result"})

    
    
    for product in products:
        # Extract the product title
        title_tag = product.find("h2")
        if not title_tag:
            continue
        title_text = title_tag.get_text(strip=True)

        
        # Extract the product price
        price_tag = product.find("span", {"class": "a-price-whole"})
        price_text = price_tag.get_text(strip=True) if price_tag else "N/A"
        
        # Extract the product brand
        match = re.match(r'^\W*([A-Za-z]+)', title_text)
        brand = match.group(1).upper() if match else "UNKNOWN"

        # Extract RAM (improved version)
        ram_match = re.search(r'(\d+)\s*GB\s*(RAM|DDR\d+|LPDDR\d+)', title_text, re.IGNORECASE)
        ram = ram_match.group(1) + "GB" if ram_match else "N/A"
        
        # Extract the product rating 
        rating_tag = product.find("span", class_="a-icon-alt")
        rating = "N/A"
        if rating_tag:
            rating_match = re.search(r'(\d+\.?\d*)', rating_tag.get_text())
            rating = rating_match.group(1) if rating_match else "N/A"

        # Extract the Product SSD - Simplified
        ssd_match = re.search(r'(\d+)\s*(GB|TB)\s*(?:SSD|NVMe)', title_text, re.IGNORECASE) or re.search(r'(\d+)\s*(GB|TB)', title_text)
        ssd = (ssd_match.group(1) + ssd_match.group(2).upper()) if ssd_match else "N/A"
      

        # Extract the Product Windows Version - Improved version
        windows_version = "N/A"
        
        # Try: "Windows 11", "Windows 10", "Win11", "Win10", etc.
        windows_match = re.search(r'(?:Windows\s*|Win\s*)(\d+)', title_text, re.IGNORECASE)
        if windows_match:
            windows_version = "Windows " + windows_match.group(1)
        
        # Extract the Product Color
        color_match = re.search(r'\b(Black|Silver|Gray|Grey|White|Blue|Red|Gold|Green|Brown|Pink|Purple|Yellow|Orange|Champagne|Midnight|Space|Cosmic|Stardust|Graphite|Ash|Onyx|Platinum|Metallic)\b', title_text, re.IGNORECASE)
        color = color_match.group(1) if color_match else "N/A"

        # Extract the Processor (Intel, AMD, Apple M, etc)
        processor = "N/A"
        
        # Try Intel processors - more flexible patterns
        intel_match = re.search(r'Intel\s+(?:Core\s+)?(?:i[3579]|m\d|Pentium|Celeron|Atom|Xeon)[-\w]*', title_text, re.IGNORECASE)
        if intel_match:
            processor = intel_match.group(0).strip()
        
        # Try AMD Ryzen/Athlon processors
        elif re.search(r'AMD', title_text, re.IGNORECASE):
            amd_match = re.search(r'AMD\s+(?:Ryzen|Athlon)[\s\w]*', title_text, re.IGNORECASE)
            if amd_match:
                processor = amd_match.group(0).strip()
        
        # Try Apple M series
        elif re.search(r'Apple\s+M', title_text, re.IGNORECASE):
            apple_match = re.search(r'Apple\s+M\d+\w*', title_text, re.IGNORECASE)
            if apple_match:
                processor = apple_match.group(0).strip()
        
        # Try other processors
        else:
            other_match = re.search(r'Qualcomm\s+Snapdragon|MediaTek|ARM|Exynos', title_text, re.IGNORECASE)
            if other_match:
                processor = other_match.group(0).strip()


        # Store the extracted data in a dictionary and append to the list
        data.append({
            "Title": title_text,
            "Price": price_text,
            "Brand": brand,
            'RAM': ram,
            "Rating": rating,
            "Storage": ssd,
            "Windows": windows_version,
            "Color": color,
            "Processor": processor
            
        })

      
    print(f"Page {page} scraped")
    time.sleep(1)
# Out:
# Page 1 scraped

# %%
for product in data:
    print("Title:", product["Title"])
    print("Price:", product["Price"])
    print("Brand:", product["Brand"])
    print("RAM:", product.get("RAM"))
    print("Processor:", product.get("Processor"))
    print("Rating:", product.get("Rating"))
    print("Storage:", product.get("Storage"))
    print("Windows:", product.get("Windows"))
    print("Color:", product.get("Color"))
    print("-" * 50)
# Out:
# Title: ASUS Vivobook S14,Smartchoice,AMD Ryzen AI 7 350,16GB RAM,1TB SSD,OLED,14",Windows 11, Office24,M365 Basic (1Yr)*, Matte Gray,1.4Kg, M3407KA-SF049WS,50 Tops,Metallic Design,Next-Gen AI Laptop,Copilot+
# Price: 83,990
# Brand: ASUS
# RAM: 16GB
# Processor: None
# Rating: 3.8
# Storage: 1TB
# Windows: Windows 11
# Color: Gray
# --------------------------------------------------
# Title: HP Omnibook 5 OLED, Snapdragon X Processor (16GB LPDDR5x,1TB SSD) 2K OLED, Micro-Edge, 16''/40.6cm, Win11, M365*Office24, Glacier Silver, 1.59kg, fb0001QU, FHD Camera, Backlit, Next-Gen AI Laptop
# Price: 69,990
# Brand: HP
# RAM: 16GB
# Processor: None
# Rating: 4.1
# Storage: 1TB
# Windows: Windows 11
# Color: Silver
# --------------------------------------------------
# Title: HP 15, 13th Gen Intel Core i3-1315U (12GB DDR4, 512GB SSD) FHD, Anti-Glare, Micro-Edge, 15.6''/39.6cm, Win11, M365 Basic(1yr)* Office24, Silver, 1.59kg, fd0573TU, FHD Camera w/Shutter Laptop
# Price: 41,990
# Brand: HP
# RAM: 12GB
# Processor: None
# Rating: 4.1
# Storage: 512GB
# Windows: Windows 11
# Color: Silver
# --------------------------------------------------
# Title: EBook 11.6" HD Laptop | Best Student & Office Work Laptop | Celeron N4020 | 4GB DDR4 | 128GB eMMC + M.2 SSD Expandable Slot | Win 11 Home |31Wh Battery | UHD Graphics 600 | Black
# Price: 10,990
# Brand: EBOOK
# RAM: 4GB
# Processor: None
# Rating: 3.5
# Storage: 4GB
# Windows: Windows 11
# Color: Black
# --------------------------------------------------
# Title: MSI Thin 15, Intel 13th Gen. Core i5-13420H, 40CM FHD 144Hz Gaming Laptop(16GB/512GB NVMe SSD/Windows 11 Home/NVIDIA GeForce RTX 3050,GDDR6 4GB/Cosmos Gray/1.86Kg), B13UC-1805IN
# Price: 60,525
# Brand: MSI
# RAM: N/A
# Processor: None
# Rating: 4.2
# Storage: 512GB
# Windows: Windows 11
# Color: Gray
# --------------------------------------------------
# Title: JioBook 11 with Lifetime Office | Android 4G Laptop Mediatek 8788 (JioOS) | Octa-core | 4GB RAM | 64 eMMC Storage | Thin and Light Laptop (11.6 inch, 990 Grams) | Dual Band WiFi + SIM | Blue
# Price: 10,990
# Brand: JIOBOOK
# RAM: 4GB
# Processor: None
# Rating: 2.9
# Storage: 4GB
# Windows: N/A
# Color: Blue
# --------------------------------------------------
# Title: Dell 15, Intel Core i5 13th Gen-1334U, 16GB RAM, 1TB SSD, FHD, 15.6"/39.62cm, Windows 11, MSO 2024, Silver, 1.62kg, [Dell 15], Backlit Keyboard, 15 Month McAfee, Thin & Light, Laptop
# Price: 57,926
# Brand: DELL
# RAM: 16GB
# Processor: None
# Rating: 3.7
# Storage: 1TB
# Windows: Windows 11
# Color: Silver
# --------------------------------------------------
# Title: ASUS Vivobook 15, Smartchoice, AMD Ryzen 7 5825U, 16GB RAM, 512GB SSD, FHD 15.6", Windows 11, Office Home 2024, Quiet Blue, 1.7Kg, M1502YA-BQ703WS, AMD Radeon iGPU, M365 Basic (1Year)*, 42Whr Laptop
# Price: 48,990
# Brand: ASUS
# RAM: 16GB
# Processor: None
# Rating: 4.3
# Storage: 512GB
# Windows: Windows 11
# Color: Blue
# --------------------------------------------------
# Title: BrowseBook 14.1" FHD IPS Laptop | Best Student & Office Work Laptop | Celeron N4020 | 4GB RAM | 128GB SSD | Windows 11 | 38Wh | 1.3kg | Grey
# Price: 12,990
# Brand: BROWSEBOOK
# RAM: 4GB
# Processor: None
# Rating: 3.0
# Storage: 128GB
# Windows: Windows 11
# Color: Grey
# --------------------------------------------------
# Title: HP 15, AMD Ryzen 3 7320U (8GB DDR4, 512GB SSD) FHD, Anti-Glare, Micro-Edge, 15.6''/39.6cm, Win11, M365 Basic(1yr)* Office24, Silver, 1.59kg, fc0500AU, FHD Camera w/Privacy Shutter Laptop
# Price: 36,990
# Brand: HP
# RAM: 8GB
# Processor: None
# Rating: 4.0
# Storage: 512GB
# Windows: Windows 11
# Color: Silver
# --------------------------------------------------
# Title: Dell 15, Intel Core i5 13th Gen-1334U Processor, 16GB DDR4, 512GB SSD, FHD, 15.6"/39.62cm, Windows 11, MSO 2024, Grey, 1.66kg, [Vostro 3530], 120Hz 250 nits, 15 Month McAfee, Thin & Light, Laptop
# Price: 56,990
# Brand: DELL
# RAM: 16GB
# Processor: None
# Rating: 3.7
# Storage: 512GB
# Windows: Windows 11
# Color: Grey
# --------------------------------------------------
# Title: Primebook 2 Max 2025 (New Launch) | 8GB RAM, 256GB UFS Storage | 15.6-Inch Full HD IPS Display | 12hrs Battery | MediaTek Helio G99 | Android 15 (PrimeOS 3.0) | Backlit Keyboard | in-Built AI (Gray)
# Price: 22,990
# Brand: PRIMEBOOK
# RAM: 8GB
# Processor: None
# Rating: 4.3
# Storage: 8GB
# Windows: N/A
# Color: Gray
# --------------------------------------------------
# Title: acer Nitro V 15, AMD Ryzen 7-7445HS, NVIDIA GeForce RTX 4050-6 GB, 16GB DDR5, 512GB SSD, FHD IPS, 15.6"/39.62cm, 165Hz, Win 11 Home, Obsidian Black, 2.1KG, ANV15-42, Gaming Laptop
# Price: 76,990
# Brand: ACER
# RAM: 16GB
# Processor: None
# Rating: 3.7
# Storage: 512GB
# Windows: Windows 11
# Color: Black
# --------------------------------------------------
# Title: Lenovo V15 Intel Core i3 13th Gen (16GB RAM/512GB SSD/Windows 11 Home/Office 2024/Iron Grey) 15.6" FHD (1920x1080) Antiglare 250 Nits Thin & Light Laptop/1Y Onsite/1.65 kg, 83CCA08KIN
# Price: N/A
# Brand: LENOVO
# RAM: 16GB
# Processor: None
# Rating: 3.9
# Storage: 512GB
# Windows: Windows 11
# Color: Grey
# --------------------------------------------------
# Title: Lenovo IdeaPad Slim 3, 12th Gen Intel Core i5-12450H (16GB LPDDR5, 512GB SSD), Anti-glare, FHD 15.6"(39.6cm), Win 11, Office Home 2024, Arctic Grey, 1.62Kg, 83ER00MDIN, Thin & Light, Backlit KB Laptop
# Price: 51,777
# Brand: LENOVO
# RAM: 16GB
# Processor: None
# Rating: 4.2
# Storage: 512GB
# Windows: Windows 11
# Color: Grey
# --------------------------------------------------
# Title: acer Aspire Go 14,14th Gen, Intel Core Ultra 5 125H, 16GB DDR5, 512GB, WUXGA IPS, 14.0"/35.56cm, Win 11, MS Office, Steel Gray, 1.5 kg, AG14-71M, Backlit KB, AI Powered Laptop
# Price: 54,427
# Brand: ACER
# RAM: 16GB
# Processor: None
# Rating: 3.6
# Storage: 16GB
# Windows: Windows 11
# Color: Gray
# --------------------------------------------------
# Title: Lenovo {SmartChoice)Chromebook Intel Celeron N4500 (4GB RAM/64GB eMMC 5.1/11.6 Inch (29.46cm)/HD Display/2Wx2 Stereo Speakers/HD Camera/Chrome OS/Blue/1.21Kg), 82UY0014HA
# Price: 17,990
# Brand: LENOVO
# RAM: 4GB
# Processor: None
# Rating: 3.9
# Storage: 4GB
# Windows: N/A
# Color: Blue
# --------------------------------------------------
# Title: HP 15 Consumer Series Laptop, Intel Core i3-1315U (13th Gen) 12GB DDR4 RAM,512GB NVMe SSD/ 15.6'' FHD Anti-Glare, Micro-Edge, Win11, M365 Basic(1yr)* Office24, Silver,1.59kg, FHD Camera with Shutter
# Price: 41,990
# Brand: HP
# RAM: 12GB
# Processor: None
# Rating: 4.1
# Storage: 512GB
# Windows: Windows 11
# Color: Silver
# --------------------------------------------------
# Title: HP OmniBook 5 OLED (Previously Pavilion), Snapdragon X Processor (16GB LPDDR5x, 512GB SSD) 2K, 14''/35.6cm, Win11, M365 Basic(1yr)* Office24, Silver, 1.35kg, he0014QU, Light-Weight, Next-Gen AI Laptop
# Price: 66,990
# Brand: HP
# RAM: 16GB
# Processor: None
# Rating: 4.1
# Storage: 512GB
# Windows: Windows 11
# Color: Silver
# --------------------------------------------------
# Title: ASUS Vivobook 15 (2025), 13th Gen,Intel Core i3-1315U, 8GB RAM, 512GB SSD, FHD, 15.6", 39.6 cm, Windows 11 Home,M365 Basic(1 Year)* Office 2024,Cool Silver,1.7 Kg, X1504VA-D5321WS, Thin & Light Laptop
# Price: 37,927
# Brand: ASUS
# RAM: 8GB
# Processor: None
# Rating: 5.0
# Storage: 512GB
# Windows: Windows 11
# Color: Silver
# --------------------------------------------------
# Title: Primebook 2 Pro 2025 (New Launch) | 8GB RAM, 128GB UFS Storage | 14.1-Inch FHD IPS Display | 14 Hours Battery | MediaTek Helio G99 | Android 15 (PrimeOS 3.0) | Backlit Keyboard | in-Built AI (Gray)
# Price: 19,990
# Brand: PRIMEBOOK
# RAM: 8GB
# Processor: None
# Rating: 4.4
# Storage: 8GB
# Windows: N/A
# Color: Gray
# --------------------------------------------------
# Title: Dell 14, AMD Ryzen AI R5-340, 16GB LPDDR5X, 512GB SSD, FHD+, 14"/35.56cm, Win11, MSO 2024, Ice Blue, 1.52 Kg, [Dell 14], 300 Nits IPS, AMD Radeon Graphics, Backlit+FPS Keyboard, AI Powered Laptop
# Price: 73,490
# Brand: DELL
# RAM: 16GB
# Processor: None
# Rating: 3.7
# Storage: 512GB
# Windows: Windows 11
# Color: Blue
# --------------------------------------------------
# Title: HP OmniBook 7 OLED, Intel Core Ultra 5 255H (16GB LPDDR5,1TB SSD), 3K, 0.2 ms, Micro-Edge, 14''/35.6cm, Win 11, M365, Office 24, Meteor Silver,1.5kg, fr0789TU, 5MP Camera w/Shutter, Backlit AI Laptop
# Price: 86,490
# Brand: HP
# RAM: 16GB
# Processor: N/A
# Rating: 3.7
# Storage: 1TB
# Windows: Windows 11
# Color: Silver
# --------------------------------------------------
# Title: HP Omnibook 5 OLED, Snapdragon X Processor (16GB LPDDR5x,1TB SSD) 2K OLED, Micro-Edge, 16''/40.6cm, Win11, M365*Office24, Glacier Silver, 1.59kg, fb0001QU, FHD Camera, Backlit, Next-Gen AI Laptop
# Price: 69,990
# Brand: HP
# RAM: 16GB
# Processor: N/A
# Rating: 4.1
# Storage: 1TB
# Windows: Windows 11
# Color: Silver
# --------------------------------------------------
# Title: EBook 11.6" HD Laptop | Best Student & Office Work Laptop | Celeron N4020 | 4GB DDR4 | 128GB eMMC + M.2 SSD Expandable Slot | Win 11 Home |31Wh Battery | UHD Graphics 600 | Black
# Price: 10,990
# Brand: EBOOK
# RAM: 4GB
# Processor: N/A
# Rating: 3.5
# Storage: 4GB
# Windows: Windows 11
# Color: Black
# --------------------------------------------------
# Title: JioBook 11 with Lifetime Office | Android 4G Laptop Mediatek 8788 (JioOS) | Octa-core | 4GB RAM | 64 eMMC Storage | Thin and Light Laptop (11.6 inch, 990 Grams) | Dual Band WiFi + SIM | Blue
# Price: 10,990
# Brand: JIOBOOK
# RAM: 4GB
# Processor: Mediatek
# Rating: 2.9
# Storage: 4GB
# Windows: N/A
# Color: Blue
# --------------------------------------------------
# Title: BrowseBook 14.1" FHD IPS Laptop | Best Student & Office Work Laptop | Celeron N4020 | 4GB RAM | 128GB SSD | Windows 11 | 38Wh | 1.3kg | Grey
# Price: 12,990
# Brand: BROWSEBOOK
# RAM: 4GB
# Processor: N/A
# Rating: 3.0
# Storage: 128GB
# Windows: Windows 11
# Color: Grey
# --------------------------------------------------
# Title: HP 15, AMD Ryzen 3 7320U (8GB DDR4, 512GB SSD) FHD, Anti-Glare, Micro-Edge, 15.6''/39.6cm, Win11, M365 Basic(1yr)* Office24, Silver, 1.59kg, fc0500AU, FHD Camera w/Privacy Shutter Laptop
# Price: 36,990
# Brand: HP
# RAM: 8GB
# Processor: AMD Ryzen 3
# Rating: 4.0
# Storage: 512GB
# Windows: Windows 11
# Color: Silver
# --------------------------------------------------
# Title: HP 15, 13th Gen Intel Core i3-1315U (12GB DDR4, 512GB SSD) FHD, Anti-Glare, Micro-Edge, 15.6''/39.6cm, Win11, M365 Basic(1yr)* Office24, Silver, 1.59kg, fd0573TU, FHD Camera w/Shutter Laptop
# Price: 41,990
# Brand: HP
# RAM: 12GB
# Processor: Intel Core i3
# Rating: 4.1
# Storage: 512GB
# Windows: Windows 11
# Color: Silver
# --------------------------------------------------
# Title: Lenovo {SmartChoice)Chromebook Intel Celeron N4500 (4GB RAM/64GB eMMC 5.1/11.6 Inch (29.46cm)/HD Display/2Wx2 Stereo Speakers/HD Camera/Chrome OS/Blue/1.21Kg), 82UY0014HA
# Price: N/A
# Brand: LENOVO
# RAM: 4GB
# Processor: N/A
# Rating: 3.9
# Storage: 4GB
# Windows: N/A
# Color: Blue
# --------------------------------------------------
# Title: Thomson NEO 14.1 Inch IN-N14C Intel Celeron Dual Core N4020 Processor Windows 11 Home Notebook (8 GB RAM DDR4/ 256 GB SSD/Thin & Light Weight/Silver/Non Stop Performance Beyond 15 Hrs)
# Price: 17,990
# Brand: THOMSON
# RAM: 8GB
# Processor: N/A
# Rating: 4.5
# Storage: 256GB
# Windows: Windows 11
# Color: Silver
# --------------------------------------------------
# Title: HP 15 Consumer Series Laptop, Intel Core i3-1315U (13th Gen) 12GB DDR4 RAM,512GB NVMe SSD/ 15.6'' FHD Anti-Glare, Micro-Edge, Win11, M365 Basic(1yr)* Office24, Silver,1.59kg, FHD Camera with Shutter
# Price: 41,990
# Brand: HP
# RAM: 12GB
# Processor: Intel Core i3
# Rating: 4.1
# Storage: 512GB
# Windows: Windows 11
# Color: Silver
# --------------------------------------------------
# Title: EooCoo Case Compatible for Apple MacBook Air 13.6 inch M4 A3240 M3 A3113 M2 A2681 with Touch ID,2026 2025 2024 2022,M2 M3 M4 Air 13'' Laptop Protective Plastic Hard Shell Cover Smooth, Midnight Clear
# Price: 1,139
# Brand: EOOCOO
# RAM: N/A
# Processor: N/A
# Rating: 4.1
# Storage: N/A
# Windows: N/A
# Color: Midnight
# --------------------------------------------------
# Title: Lenovo Ideapad Slim 3 AMD Ryzen 5 7520U 15.6" (39.6cm) FHD Thin and Light Laptop (16GB/512GB SSD/Windows 11/Microsoft 365 Basic + Office Home 2024/Backlit Keyboard/Grey/1.6Kg), 82XQ00XDIN
# Price: 45,790
# Brand: LENOVO
# RAM: N/A
# Processor: AMD Ryzen 5
# Rating: 4.0
# Storage: 512GB
# Windows: Windows 11
# Color: Grey
# --------------------------------------------------
# Title: ASUS Vivobook 14, Intel Core i3 13th Gen 1315U, 8GB RAM, 512GB SSD, FHD 14", Windows 11, Office Home 2024, Cool Silver, 1.40kg, X1404VA-NK761WS, Intel UHD, M365 Basic (1Year)*, Backlit Keyboard Laptop
# Price: 36,650
# Brand: ASUS
# RAM: 8GB
# Processor: Intel Core i3
# Rating: 3.9
# Storage: 512GB
# Windows: Windows 11
# Color: Silver
# --------------------------------------------------
# Title: HP 14s Intel Celeron Dual Core N4500 Laptop (8GB/512GB SSD/Win 11) 14.0" HD Display, MSO 24, Black, 1.46kg, DQ3149TU Thin and Light Business Laptop
# Price: 28,690
# Brand: HP
# RAM: N/A
# Processor: N/A
# Rating: 3.3
# Storage: 512GB
# Windows: Windows 11
# Color: Black
# --------------------------------------------------
# Title: ASUS Vivobook Go 14, AMD Ryzen 3 7320U, 8GB RAM, 512GB SSD, FHD 14", Windows 11, Office Home 2024, Mixed Black, 1.38 kg, E1404FA-NK3325WS, AMD Radeon iGPU, M365 Basic (1Year)*, Thin & Light Laptop
# Price: 34,790
# Brand: ASUS
# RAM: 8GB
# Processor: AMD Ryzen 3
# Rating: 4.1
# Storage: 512GB
# Windows: Windows 11
# Color: Black
# --------------------------------------------------
# Title: Dell 15, Intel Core i3 13th Gen -1305U, 16GB DDR4, 512GB SSD, FHD, 15.6"/39.6cm, Windows 11, Office H&S 2024, Carbon Grey, 1.66Kg, [Vostro 3530], Intel UHD Graphics, Narrow Border, Thin & Light Laptop
# Price: 42,990
# Brand: DELL
# RAM: 16GB
# Processor: Intel Core i3
# Rating: 3.9
# Storage: 512GB
# Windows: Windows 11
# Color: Grey
# --------------------------------------------------
# Title: Thomson NEO 14.1 Inch IN-P14C Intel Celeron Dual Core N4020 Processor & Window 11 Home Notebook (4 GB RAM DDR4/ 128 GB SSD/Numeric Touch Pad/Thin & Light Weight/Silver)
# Price: 12,990
# Brand: THOMSON
# RAM: 4GB
# Processor: N/A
# Rating: 3.0
# Storage: 128GB
# Windows: N/A
# Color: Silver
# --------------------------------------------------
# Title: HP 15 Laptop, AMD Ryzen 7 5825U [16GB DDR4,512GB SSD] [Win11, Office Home'2024/M365 Basic(1yr)*] [Anti-Glare,Micro-Edge,15.6''/39.6cm FHD]Silver,1.59kg [Backlit KB+FHD Camera+Radeon Graphics] fc0533AU
# Price: 49,990
# Brand: HP
# RAM: 16GB
# Processor: AMD Ryzen 7
# Rating: 3.9
# Storage: 512GB
# Windows: Windows 11
# Color: Silver
# --------------------------------------------------
# Title: acer Aspire 3, Intel Core Celeron N4500, 12GB LPDDR4X RAM, 512GB SSD, HD, 15.6"/39.62cm, Windows 11 Home, Pure Silver, 1.5KG, A325-45, Thin and Light Laptop
# Price: 31,999
# Brand: ACER
# RAM: 12GB
# Processor: Intel Core Celeron
# Rating: 3.4
# Storage: 512GB
# Windows: Windows 11
# Color: Silver
# --------------------------------------------------
# Title: Walker Best Student & Office Work Laptop|Thin & Light|15.6" 1920 * 1080 Resolution FHD IPS Display |8GB RAM,256 GB SSD|Intel Celeron Processor N4020 | Windows 11 Home |Silver
# Price: 16,990
# Brand: WALKER
# RAM: 8GB
# Processor: N/A
# Rating: 3.0
# Storage: 256GB
# Windows: Windows 11
# Color: Silver
# --------------------------------------------------
# Title: Epson EcoTank L3252 Wi-Fi All-in-One Ink Tank Printer (Black)
# Price: 13,399
# Brand: EPSON
# RAM: N/A
# Processor: N/A
# Rating: 4.0
# Storage: N/A
# Windows: N/A
# Color: Black
# --------------------------------------------------
# Title: Lenovo IdeaPad Slim 3 Ryzen 7 5825U 15.6" (39.6cm) FHD Thin and Light Laptop (16GB RAM/512GB SSD/Integrated AMD Radeon Graphics/Windows 11/Office Home 2024/Grey/1.6Kg), 82XM0114IN
# Price: 49,990
# Brand: LENOVO
# RAM: 16GB
# Processor: N/A
# Rating: 3.9
# Storage: 512GB
# Windows: Windows 11
# Color: Grey
# --------------------------------------------------
# Title: Lenovo Ideapad Slim 3 AMD Ryzen 5 7520U 15.6" (39.6cm) FHD Thin and Light Laptop (16GB/512GB SSD/Windows 11/Microsoft 365 Basic + Office Home 2024/Backlit Keyboard/Grey/1.6Kg), 82XQ00XDIN
# Price: 45,790
# Brand: LENOVO
# RAM: N/A
# Processor: AMD Ryzen 5 7520U
# Rating: 4.0
# Storage: 512GB
# Windows: Windows 11
# Color: Grey
# --------------------------------------------------
# Title: Lenovo IdeaPad Slim 3 Ryzen 7 5825U 15.6" (39.6cm) FHD Thin and Light Laptop (16GB RAM/512GB SSD/Integrated AMD Radeon Graphics/Windows 11/Office Home 2024/Grey/1.6Kg), 82XM0114IN
# Price: 49,990
# Brand: LENOVO
# RAM: 16GB
# Processor: N/A
# Rating: 3.9
# Storage: 512GB
# Windows: Windows 11
# Color: Grey
# --------------------------------------------------
# Title: HP 15, 13th Gen Intel Core i3-1315U (12GB DDR4, 512GB SSD) FHD, Anti-Glare, Micro-Edge, 15.6''/39.6cm, Win11, M365 Basic(1yr)* Office24, Silver, 1.59kg, fd0573TU, FHD Camera w/Shutter Laptop
# Price: 41,990
# Brand: HP
# RAM: 12GB
# Processor: Intel Core i3-1315U
# Rating: 4.1
# Storage: 512GB
# Windows: Windows 11
# Color: Silver
# --------------------------------------------------
# Title: EBook 11.6" HD Laptop | Best Student & Office Work Laptop | Celeron N4020 | 4GB DDR4 | 128GB eMMC + M.2 SSD Expandable Slot | Win 11 Home |31Wh Battery | UHD Graphics 600 | Black
# Price: 10,990
# Brand: EBOOK
# RAM: 4GB
# Processor: N/A
# Rating: 3.5
# Storage: 4GB
# Windows: Windows 11
# Color: Black
# --------------------------------------------------
# Title: JioBook 11 with Lifetime Office | Android 4G Laptop Mediatek 8788 (JioOS) | Octa-core | 4GB RAM | 64 eMMC Storage | Thin and Light Laptop (11.6 inch, 990 Grams) | Dual Band WiFi + SIM | Blue
# Price: 10,990
# Brand: JIOBOOK
# RAM: 4GB
# Processor: Mediatek
# Rating: 2.9
# Storage: 4GB
# Windows: N/A
# Color: Blue
# --------------------------------------------------
# Title: MSI Thin 15, Intel 13th Gen. Core i5-13420H, 40CM FHD 144Hz Gaming Laptop(16GB/512GB NVMe SSD/Windows 11 Home/NVIDIA GeForce RTX 3050,GDDR6 4GB/Cosmos Gray/1.86Kg), B13UC-1805IN
# Price: 60,525
# Brand: MSI
# RAM: N/A
# Processor: N/A
# Rating: 4.2
# Storage: 512GB
# Windows: Windows 11
# Color: Gray
# --------------------------------------------------
# Title: HP 15, AMD Ryzen 3 7320U (8GB DDR4, 512GB SSD) FHD, Anti-Glare, Micro-Edge, 15.6''/39.6cm, Win11, M365 Basic(1yr)* Office24, Silver, 1.59kg, fc0500AU, FHD Camera w/Privacy Shutter Laptop
# Price: 36,990
# Brand: HP
# RAM: 8GB
# Processor: AMD Ryzen 3 7320U
# Rating: 4.0
# Storage: 512GB
# Windows: Windows 11
# Color: Silver
# --------------------------------------------------
# Title: Lenovo {SmartChoice)Chromebook Intel Celeron N4500 (4GB RAM/64GB eMMC 5.1/11.6 Inch (29.46cm)/HD Display/2Wx2 Stereo Speakers/HD Camera/Chrome OS/Blue/1.21Kg), 82UY0014HA
# Price: N/A
# Brand: LENOVO
# RAM: 4GB
# Processor: Intel Celeron
# Rating: 3.9
# Storage: 4GB
# Windows: N/A
# Color: Blue
# --------------------------------------------------
# Title: ASUS Vivobook 15, Smartchoice, AMD Ryzen 7 5825U, 16GB RAM, 512GB SSD, FHD 15.6", Windows 11, Office Home 2024, Quiet Blue, 1.7Kg, M1502YA-BQ703WS, AMD Radeon iGPU, M365 Basic (1Year)*, 42Whr Laptop
# Price: 48,990
# Brand: ASUS
# RAM: 16GB
# Processor: AMD Ryzen 7 5825U
# Rating: 4.3
# Storage: 512GB
# Windows: Windows 11
# Color: Blue
# --------------------------------------------------
# Title: Lenovo V15 Intel Core i3 13th Gen (16GB RAM/512GB SSD/Windows 11 Home/Office 2024/Iron Grey) 15.6" FHD (1920x1080) Antiglare 250 Nits Thin & Light Laptop/1Y Onsite/1.65 kg, 83CCA08KIN
# Price: N/A
# Brand: LENOVO
# RAM: 16GB
# Processor: Intel Core i3
# Rating: 3.9
# Storage: 512GB
# Windows: Windows 11
# Color: Grey
# --------------------------------------------------
# Title: Primebook 2 Max 2025 (New Launch) | 8GB RAM, 256GB UFS Storage | 15.6-Inch Full HD IPS Display | 12hrs Battery | MediaTek Helio G99 | Android 15 (PrimeOS 3.0) | Backlit Keyboard | in-Built AI (Gray)
# Price: 22,990
# Brand: PRIMEBOOK
# RAM: 8GB
# Processor: MediaTek
# Rating: 4.3
# Storage: 8GB
# Windows: N/A
# Color: Gray
# --------------------------------------------------
# Title: Primebook 2 Pro 2025 (New Launch) | 8GB RAM, 128GB UFS Storage | 14.1-Inch FHD IPS Display | 14 Hours Battery | MediaTek Helio G99 | Android 15 (PrimeOS 3.0) | Backlit Keyboard | in-Built AI (Gray)
# Price: 19,990
# Brand: PRIMEBOOK
# RAM: 8GB
# Processor: MediaTek
# Rating: 4.4
# Storage: 8GB
# Windows: N/A
# Color: Gray
# --------------------------------------------------
# Title: Dell 15, Intel Core i5 13th Gen-1334U Processor, 16GB DDR4, 512GB SSD, FHD, 15.6"/39.62cm, Windows 11, MSO 2024, Grey, 1.66kg, [Vostro 3530], 120Hz 250 nits, 15 Month McAfee, Thin & Light, Laptop
# Price: 56,990
# Brand: DELL
# RAM: 16GB
# Processor: Intel Core i5
# Rating: 3.7
# Storage: 512GB
# Windows: Windows 11
# Color: Grey
# --------------------------------------------------
# Title: acer Aspire Go 14,14th Gen, Intel Core Ultra 5 125H, 16GB DDR5, 512GB, WUXGA IPS, 14.0"/35.56cm, Win 11, MS Office, Steel Gray, 1.5 kg, AG14-71M, Backlit KB, AI Powered Laptop
# Price: 54,427
# Brand: ACER
# RAM: 16GB
# Processor: N/A
# Rating: 3.6
# Storage: 16GB
# Windows: Windows 11
# Color: Gray
# --------------------------------------------------
# Title: BrowseBook 14.1" FHD IPS Laptop | Best Student & Office Work Laptop | Celeron N4020 | 4GB RAM | 128GB SSD | Windows 11 | 38Wh | 1.3kg | Grey
# Price: 12,990
# Brand: BROWSEBOOK
# RAM: 4GB
# Processor: N/A
# Rating: 3.0
# Storage: 128GB
# Windows: Windows 11
# Color: Grey
# --------------------------------------------------
# Title: acer Nitro V 15, AMD Ryzen 7-7445HS, NVIDIA GeForce RTX 4050-6 GB, 16GB DDR5, 512GB SSD, FHD IPS, 15.6"/39.62cm, 165Hz, Win 11 Home, Obsidian Black, 2.1KG, ANV15-42, Gaming Laptop
# Price: 76,990
# Brand: ACER
# RAM: 16GB
# Processor: N/A
# Rating: 3.7
# Storage: 512GB
# Windows: Windows 11
# Color: Black
# --------------------------------------------------
# Title: Lenovo IdeaPad Slim 3, 12th Gen Intel Core i5-12450H (16GB LPDDR5, 512GB SSD), Anti-glare, FHD 15.6"(39.6cm), Win 11, Office Home 2024, Arctic Grey, 1.62Kg, 83ER00MDIN, Thin & Light, Backlit KB Laptop
# Price: 51,616
# Brand: LENOVO
# RAM: 16GB
# Processor: Intel Core i5-12450H
# Rating: 4.2
# Storage: 512GB
# Windows: Windows 11
# Color: Grey
# --------------------------------------------------
# Title: HP OmniBook 5 OLED (Previously Pavilion), Snapdragon X Processor (16GB LPDDR5x, 512GB SSD) 2K, 14''/35.6cm, Win11, M365 Basic(1yr)* Office24, Silver, 1.35kg, he0014QU, Light-Weight, Next-Gen AI Laptop
# Price: 66,990
# Brand: HP
# RAM: 16GB
# Processor: N/A
# Rating: 4.1
# Storage: 512GB
# Windows: Windows 11
# Color: Silver
# --------------------------------------------------
# Title: ASUS Gaming V16 (2025) 14th Gen,Intel Core 7 240H Gaming Laptop (RTX 4050-6GB/16GB RAM/512GB SSD/Windows 11 Home/16/144Hz/M365*/Office Home 2024, Matte Black,1.95 Kg),V3607VU-RP275WS
# Price: 92,990
# Brand: ASUS
# RAM: 16GB
# Processor: N/A
# Rating: 4.2
# Storage: 512GB
# Windows: Windows 11
# Color: Black
# --------------------------------------------------
# Title: ASUS Vivobook 15 (2025), 13th Gen,Intel Core i3-1315U, 8GB RAM, 512GB SSD, FHD, 15.6", 39.6 cm, Windows 11 Home,M365 Basic(1 Year)* Office 2024,Cool Silver,1.7 Kg, X1504VA-D5321WS, Thin & Light Laptop
# Price: 37,927
# Brand: ASUS
# RAM: 8GB
# Processor: Intel Core i3-1315U
# Rating: 5.0
# Storage: 512GB
# Windows: Windows 11
# Color: Silver
# --------------------------------------------------
# Title: MSI Katana 15 HX, Intel 14th Gen. i5-14450HX, 40CM FHD 144Hz Gaming Laptop (16GB/512GB NVMe SSD/Windows 11 Home/NVIDIA GeForce RTX 5050, GDDR7 8GB/Black/2.4Kg) B14WEK-438IN
# Price: 1,02,990
# Brand: MSI
# RAM: N/A
# Processor: N/A
# Rating: N/A
# Storage: 512GB
# Windows: Windows 11
# Color: Black
# --------------------------------------------------
# Title: Lenovo LOQ, AMD Ryzen 5 7235HS, RTX 3050A-4GB, 12GB RAM, 512GB SSD, [FHD], 15.6"/39.6cm, 144Hz, Windows 11, Office Home 2024, Grey, 2.4Kg, 83JC00HNIN, 3 Mon. Game Pass, Gaming Laptop
# Price: 62,516
# Brand: LENOVO
# RAM: 12GB
# Processor: AMD Ryzen 5 7235HS
# Rating: 4.1
# Storage: 512GB
# Windows: Windows 11
# Color: Grey
# --------------------------------------------------
# Title: Dell 15, Intel Core i5 13th Gen-1334U Processor, 16GB DDR4, 512GB SSD, FHD, 15.6"/39.62cm, Windows 11, MSO 2024, Grey, 1.66kg, [Vostro 3530], 120Hz 250 nits, 15 Month McAfee, Thin & Light, Laptop
# Price: 56,990
# Brand: DELL
# RAM: 16GB
# Processor: Intel Core i5
# Rating: 3.7
# Storage: 512GB
# Windows: Windows 11
# Color: Grey
# --------------------------------------------------
# Title: Dell SmartChoice G15-5530, Intel Core i5 13th Gen - 13450HX, NVIDIA RTX 3050-6GB, 16GB RAM, 1TB SSD, FHD 15.6"/39.62 cm, Windows 11 Home, MS Office 21, Dark Shadow Grey, 2.65Kg Gaming Laptop
# Price: 77,787
# Brand: DELL
# RAM: 16GB
# Processor: Intel Core i5
# Rating: 4.0
# Storage: 1TB
# Windows: Windows 11
# Color: Grey
# --------------------------------------------------
# Title: HP 15, 13th Gen Intel Core i3-1315U (12GB DDR4, 512GB SSD) FHD, Anti-Glare, Micro-Edge, 15.6''/39.6cm, Win11, M365 Basic(1yr)* Office24, Silver, 1.59kg, fd0573TU, FHD Camera w/Shutter Laptop
# Price: 41,990
# Brand: HP
# RAM: 12GB
# Processor: Intel Core i3-1315U
# Rating: 4.1
# Storage: 512GB
# Windows: Windows 11
# Color: Silver
# --------------------------------------------------
# Title: EBook 11.6" HD Laptop | Best Student & Office Work Laptop | Celeron N4020 | 4GB DDR4 | 128GB eMMC + M.2 SSD Expandable Slot | Win 11 Home |31Wh Battery | UHD Graphics 600 | Black
# Price: 10,990
# Brand: EBOOK
# RAM: 4GB
# Processor: N/A
# Rating: 3.5
# Storage: 4GB
# Windows: Windows 11
# Color: Black
# --------------------------------------------------
# Title: JioBook 11 with Lifetime Office | Android 4G Laptop Mediatek 8788 (JioOS) | Octa-core | 4GB RAM | 64 eMMC Storage | Thin and Light Laptop (11.6 inch, 990 Grams) | Dual Band WiFi + SIM | Blue
# Price: 10,990
# Brand: JIOBOOK
# RAM: 4GB
# Processor: Mediatek
# Rating: 2.9
# Storage: 4GB
# Windows: N/A
# Color: Blue
# --------------------------------------------------
# Title: Lenovo {SmartChoice)Chromebook Intel Celeron N4500 (4GB RAM/64GB eMMC 5.1/11.6 Inch (29.46cm)/HD Display/2Wx2 Stereo Speakers/HD Camera/Chrome OS/Blue/1.21Kg), 82UY0014HA
# Price: N/A
# Brand: LENOVO
# RAM: 4GB
# Processor: Intel Celeron
# Rating: 3.9
# Storage: 4GB
# Windows: N/A
# Color: Blue
# --------------------------------------------------
# Title: MSI Thin 15, Intel 13th Gen. Core i5-13420H, 40CM FHD 144Hz Gaming Laptop(16GB/512GB NVMe SSD/Windows 11 Home/NVIDIA GeForce RTX 3050,GDDR6 4GB/Cosmos Gray/1.86Kg), B13UC-1805IN
# Price: 60,525
# Brand: MSI
# RAM: N/A
# Processor: N/A
# Rating: 4.2
# Storage: 512GB
# Windows: Windows 11
# Color: Gray
# --------------------------------------------------
# Title: HP 15, AMD Ryzen 3 7320U (8GB DDR4, 512GB SSD) FHD, Anti-Glare, Micro-Edge, 15.6''/39.6cm, Win11, M365 Basic(1yr)* Office24, Silver, 1.59kg, fc0500AU, FHD Camera w/Privacy Shutter Laptop
# Price: 36,990
# Brand: HP
# RAM: 8GB
# Processor: AMD Ryzen 3 7320U
# Rating: 4.0
# Storage: 512GB
# Windows: Windows 11
# Color: Silver
# --------------------------------------------------
# Title: ASUS Vivobook 15, Smartchoice, AMD Ryzen 7 5825U, 16GB RAM, 512GB SSD, FHD 15.6", Windows 11, Office Home 2024, Quiet Blue, 1.7Kg, M1502YA-BQ703WS, AMD Radeon iGPU, M365 Basic (1Year)*, 42Whr Laptop
# Price: 48,990
# Brand: ASUS
# RAM: 16GB
# Processor: AMD Ryzen 7 5825U
# Rating: 4.3
# Storage: 512GB
# Windows: Windows 11
# Color: Blue
# --------------------------------------------------
# Title: Lenovo V15 Intel Core i3 13th Gen (16GB RAM/512GB SSD/Windows 11 Home/Office 2024/Iron Grey) 15.6" FHD (1920x1080) Antiglare 250 Nits Thin & Light Laptop/1Y Onsite/1.65 kg, 83CCA08KIN
# Price: N/A
# Brand: LENOVO
# RAM: 16GB
# Processor: Intel Core i3
# Rating: 3.9
# Storage: 512GB
# Windows: Windows 11
# Color: Grey
# --------------------------------------------------
# Title: Dell 15, Intel Core 3, 14th Gen-100U, 8GB DDR4, 512GB SSD, FHD IPS, 15.6"/39.62cm, Win 11, Office H&S 2024, Carbon Black, 1.63Kg, Dell 15, Intel UHD Graphics, 120Hz 250 nit, Thin & Light, Laptop
# Price: 39,990
# Brand: DELL
# RAM: 8GB
# Processor: N/A
# Rating: 4.0
# Storage: 512GB
# Windows: Windows 11
# Color: Black
# --------------------------------------------------
# Title: Dell 15, Intel Core 3 14th Gen-100U, 16GB DDR4, 512GB SSD, FHD IPS, 15.6"/39.62cm, Win 11, Office H&S 2024, Carbon Black, 1.63Kg, [Dell 15], Intel UHD Graphics, 120Hz 250 nit, Thin & Light, Laptop
# Price: 44,326
# Brand: DELL
# RAM: 16GB
# Processor: N/A
# Rating: 3.9
# Storage: 512GB
# Windows: Windows 11
# Color: Black
# --------------------------------------------------
# Title: BrowseBook 14.1" FHD IPS Laptop | Best Student & Office Work Laptop | Celeron N4020 | 4GB RAM | 128GB SSD | Windows 11 | 38Wh | 1.3kg | Grey
# Price: 12,990
# Brand: BROWSEBOOK
# RAM: 4GB
# Processor: N/A
# Rating: 3.0
# Storage: 128GB
# Windows: Windows 11
# Color: Grey
# --------------------------------------------------
# Title: acer Aspire Go 14,14th Gen, Intel Core Ultra 5 125H, 16GB DDR5, 512GB, WUXGA IPS, 14.0"/35.56cm, Win 11, MS Office, Steel Gray, 1.5 kg, AG14-71M, Backlit KB, AI Powered Laptop
# Price: 54,427
# Brand: ACER
# RAM: 16GB
# Processor: N/A
# Rating: 3.6
# Storage: 16GB
# Windows: Windows 11
# Color: Gray
# --------------------------------------------------
# Title: Lenovo IdeaPad Slim 3, 12th Gen Intel Core i5-12450H (16GB LPDDR5, 512GB SSD), Anti-glare, FHD 15.6"(39.6cm), Win 11, Office Home 2024, Arctic Grey, 1.62Kg, 83ER00MDIN, Thin & Light, Backlit KB Laptop
# Price: 51,616
# Brand: LENOVO
# RAM: 16GB
# Processor: Intel Core i5-12450H
# Rating: 4.2
# Storage: 512GB
# Windows: Windows 11
# Color: Grey
# --------------------------------------------------
# Title: Dell 15, Intel Core i5 13th Gen-1334U Processor, 16GB DDR4, 512GB SSD, FHD, 15.6"/39.62cm, Windows 11, MSO 2024, Grey, 1.66kg, [Vostro 3530], 120Hz 250 nits, 15 Month McAfee, Thin & Light, Laptop
# Price: 56,990
# Brand: DELL
# RAM: 16GB
# Processor: Intel Core i5
# Rating: 3.7
# Storage: 512GB
# Windows: Windows 11
# Color: Grey
# --------------------------------------------------
# Title: acer Nitro V 15, AMD Ryzen 7-7445HS, NVIDIA GeForce RTX 4050-6 GB, 16GB DDR5, 512GB SSD, FHD IPS, 15.6"/39.62cm, 165Hz, Win 11 Home, Obsidian Black, 2.1KG, ANV15-42, Gaming Laptop
# Price: 76,990
# Brand: ACER
# RAM: 16GB
# Processor: AMD Ryzen 7
# Rating: 3.7
# Storage: 512GB
# Windows: Windows 11
# Color: Black
# --------------------------------------------------
# Title: HP OmniBook 5 OLED (Previously Pavilion), Snapdragon X Processor (16GB LPDDR5x, 512GB SSD) 2K, 14''/35.6cm, Win11, M365 Basic(1yr)* Office24, Silver, 1.35kg, he0014QU, Light-Weight, Next-Gen AI Laptop
# Price: 66,990
# Brand: HP
# RAM: 16GB
# Processor: N/A
# Rating: 4.1
# Storage: 512GB
# Windows: Windows 11
# Color: Silver
# --------------------------------------------------
# Title: ASUS Vivobook 15 (2025), 13th Gen,Intel Core i3-1315U, 8GB RAM, 512GB SSD, FHD, 15.6", 39.6 cm, Windows 11 Home,M365 Basic(1 Year)* Office 2024,Cool Silver,1.7 Kg, X1504VA-D5321WS, Thin & Light Laptop
# Price: 37,927
# Brand: ASUS
# RAM: 8GB
# Processor: Intel Core i3-1315U
# Rating: 5.0
# Storage: 512GB
# Windows: Windows 11
# Color: Silver
# --------------------------------------------------
# Title: Thomson NEO 14.1 Inch IN-N14C Intel Celeron Dual Core N4020 Processor Windows 11 Home Notebook (8 GB RAM DDR4/ 256 GB SSD/Thin & Light Weight/Silver/Non Stop Performance Beyond 15 Hrs)
# Price: 17,990
# Brand: THOMSON
# RAM: 8GB
# Processor: Intel Celeron
# Rating: 4.5
# Storage: 256GB
# Windows: Windows 11
# Color: Silver
# --------------------------------------------------
# Title: Lenovo Ideapad Slim 3 AMD Ryzen 5 7520U 15.6" (39.6cm) FHD Thin and Light Laptop (16GB/512GB SSD/Windows 11/Microsoft 365 Basic + Office Home 2024/Backlit Keyboard/Grey/1.6Kg), 82XQ00XDIN
# Price: 45,790
# Brand: LENOVO
# RAM: N/A
# Processor: AMD Ryzen 5 7520U 15
# Rating: 4.0
# Storage: 512GB
# Windows: Windows 11
# Color: Grey
# --------------------------------------------------
# Title: Lenovo IdeaPad Slim 3 Ryzen 7 5825U 15.6" (39.6cm) FHD Thin and Light Laptop (16GB RAM/512GB SSD/Integrated AMD Radeon Graphics/Windows 11/Office Home 2024/Grey/1.6Kg), 82XM0114IN
# Price: 49,990
# Brand: LENOVO
# RAM: 16GB
# Processor: N/A
# Rating: 3.9
# Storage: 512GB
# Windows: Windows 11
# Color: Grey
# --------------------------------------------------

# %%
# make data into a dataframe 
import pandas as pd

# Create a DataFrame from the data list
df = pd.DataFrame(data)
df.head()
# Out:
#                                                Title   Price  Brand   RAM  \
# 0  ASUS Vivobook S14,Smartchoice,AMD Ryzen AI 7 3...  83,990   ASUS  16GB
# 1  HP Omnibook 5 OLED, Snapdragon X Processor (16...  69,990     HP  16GB
# 2  HP 15, 13th Gen Intel Core i3-1315U (12GB DDR4...  41,990     HP  12GB
# 3  EBook 11.6" HD Laptop | Best Student & Office ...  10,990  EBOOK   4GB
# 4  MSI Thin 15, Intel 13th Gen. Core i5-13420H, 4...  60,525    MSI   N/A
#
#   Rating Storage     Windows   Color
# 0    3.8     1TB  Windows 11    Gray
# 1    4.1     1TB  Windows 11  Silver
# 2    4.1   512GB  Windows 11  Silver
# 3    3.5     4GB  Windows 11   Black
# 4    4.2   512GB  Windows 11    Gray

# %%
print("First 3 product titles:")
for i in range(min(3, len(data))):
    print(f"\n{i+1}. Title: {data[i]['Title']}")
    print(f"   Processor: {data[i]['Processor']}")
